# %%
from google.colab import files
uploaded = files.upload()
#uploaded = files.upload
# Out:
#      <input type="file" id="files-b044ec1e-4eb8-43a5-9c61-67df49419aa3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b044ec1e-4eb8-43a5-9c61-67df49419aa3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv('movies.csv')
df.head()
# Out:
#                                 MOVIES         YEAR  \
# 0                        Blood Red Sky       (2021)
# 1  Masters of the Universe: Revelation     (2021– )
# 2                     The Walking Dead  (2010–2022)
# 3                       Rick and Morty     (2013– )
# 4                      Army of Thieves       (2021)
#
#                                         GENRE  RATING  \
# 0      \nAction, Horror, Thriller                 6.1
# 1  \nAnimation, Action, Adventure                 5.0
# 2       \nDrama, Horror, Thriller                 8.2
# 3  \nAnimation, Adventure, Comedy                 9.2
# 4         \nAction, Crime, Horror                 NaN
#
#                                             ONE-LINE  \
# 0  \nA woman with a mysterious illness is forced ...
# 1  \nThe war for Eternia begins again in what may...
# 2  \nSheriff Deputy Rick Grimes wakes up from a c...
# 3  \nAn animated series that follows the exploits...
# ...

# %%
'''from google.colab import files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
uploaded = files.upload()
#uploaded = files.upload
df=pd.read_csv('movies.csv')
df.head()

# Drop rows with missing values
df.dropna(inplace=True)

# Remove duplicates
df.drop_duplicates(inplace=True)

# Convert data types
df['budget'] = df['budget'].astype(int)
df['gross'] = df['gross'].astype(int)
df['released'] = pd.to_datetime(df['released'])

# Extract year from 'released' column
df['yearcorrect'] = df['released'].dt.year

# Handle inconsistent company names
df['company'] = df['company'].str.strip()

# ... any other cleaning steps based on your dataset ...
'''
# Out:
# "from google.colab import files\nimport pandas as pd\nimport numpy as np\nimport matplotlib.pyplot as plt\nimport seaborn as sns\nuploaded = files.upload()\n#uploaded = files.upload\ndf=pd.read_csv('movies.csv')\ndf.head()\n\n# Drop rows with missing values\ndf.dropna(inplace=True)\n\n# Remove duplicates\ndf.drop_duplicates(inplace=True)\n\n# Convert data types\ndf['budget'] = df['budget'].astype(int)\ndf['gross'] = df['gross'].astype(int)\ndf['released'] = pd.to_datetime(df['released'])\n\n# Extract year from 'released' column\ndf['yearcorrect'] = df['released'].dt.year\n\n# Handle inconsistent company names\ndf['company'] = df['company'].str.strip()\n\n# ... any other cleaning steps based on your dataset ...\n"

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)
df
# Out:
#                                                  MOVIES        YEAR  \
# 77                               The Hitman's Bodyguard      (2017)
# 85                                        Jurassic Park      (1993)
# 95                                        Don't Breathe      (2016)
# 111   The Lord of the Rings: The Fellowship of the Ring      (2001)
# 125                                         Escape Room  (I) (2019)
# ...                                                 ...         ...
# 5750                           Vidal Sassoon: The Movie      (2010)
# 5770                                       Men at Lunch      (2012)
# 5835                                    Decoding Deepak      (2012)
# 6056                                     Theo Who Lived      (2016)
# 6292                                   Southern Justice      (2006)
#
#                                           GENRE  RATING  \
# 77          \nAction, Comedy, Crime                 6.9
# ...

# %%
df['Gross'] = df['Gross'].replace('[\$,]', '', regex=True)
df['Gross'] = df['Gross'].replace('M', 'e6', regex=True)
df['Gross'] = df['Gross'].astype(float)

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(df['Gross'])
plt.title('Boxplot of Gross Revenue')
plt.ylabel('Gross Revenue')
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.boxplot(df['RATING'])
plt.title('Boxplot of Ratings')
plt.ylabel('Rating')
plt.show()

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['RATING']],df.Gross)
# Out:
# LinearRegression()
